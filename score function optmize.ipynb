# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Tday = 100 # 天数 
Mt = np.random.rand(Tday)*140 +10   #120~160 float
print Mt
# Out:
# [  95.98123682  110.5607517   133.73363325  138.06789916   84.730246
#   136.57937811   90.370816     15.1507485    36.98411166   46.63162606
#   122.23823595   26.43360218   98.19842057  142.1197653   106.08105913
#    18.05320784   62.88794233   93.7177225    32.14076638  128.7336736
#    53.20896708   63.99248722   12.03779227   43.96707188  121.57941396
#    59.96084721   74.8489566    75.38603062   77.03674216   61.89502487
#    61.59706997   90.05029918  101.01239224  123.91078284   76.80905247
#   123.39616688   25.45710615  122.66799259   14.91074742  147.63364721
#   138.15429449   50.44647841   18.60629073   28.71893117  121.47444006
#    69.21145768  103.29428852   16.94651109  113.35580474  131.19304647
#   149.99215795   24.25853555  149.38792798   43.84177905  123.0722485
#    15.02948764   49.0608248    75.64029487  111.32426905  145.58629326
#    20.98693151   93.32365177  123.60348701   58.13362355   65.02718802
#   144.45588032   55.56961677   52.46803709   29.0482904   142.74517256
#   127.39156426  108.53744054   85.76465223   71.57071156   98.31421479
#   123.0666341    18.35826966  121.96977725   61.37530124  149.22909636
#   133.400323     24.05275543  134.96781387   94.26070748  123.00520352
#   141.07639771  106.25835967   62.43358937   74.47572802   56.56974499
#    50.3152294    55.39115737   83.23998921  136.64008583  128.90110585
#    83.89979568   72.40196523   26.01850878   46.71962688  114.01988338]

# %%
x = np.arange(10.0,150.0,0.1)
y = np.zeros_like(x)

# %%
for i in range(len(x)):
   y[i] = np.sum(np.fabs((x[i]-Mt)/(x[i]+Mt)))/Tday

# %%
x
# Out:
# array([  10. ,   10.1,   10.2, ...,  149.7,  149.8,  149.9])

# %%
y
# Out:
# array([ 0.71524644,  0.71298516,  0.71073227, ...,  0.32328255,
#         0.32355409,  0.3238254 ])

# %%
plt.figure(figsize=(14,7))
plt.plot(x,y)

# %%
def draw(y1,y2,Tday=20):
    # 天数 Tday  
    Mt = np.random.rand(Tday)*(y2-y1) +y1   
    x = np.arange(y1,y2,0.1)
    y = np.zeros_like(x)
    for i in range(len(x)):
        y[i] = np.sum(np.fabs((x[i]-Mt)/(x[i]+Mt)))/Tday
    plt.figure(figsize=(14,7))
    plt.plot(x,y)
    plt.title('Mt range from '+ str(y1)+ ' to '+ str(y2)+';   Tday = '+str(Tday) )

# %%
draw(10,100,10)

# %% [markdown]
# 结论 :1. 猜大不猜小?
#      2.图像成  U 型
#      3. 上升模型要特别注意?
